# %% [markdown]
# #### Geometric Transformations of Images

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('opencv_logo.png')

rows,cols,_ = img.shape

res1 = cv2.resize(img,None,fx=2, fy=2, interpolation = cv2.INTER_LINEAR)
res2 = cv2.resize(img,None,fx=2, fy=2, interpolation = cv2.INTER_AREA)
res3 = cv2.resize(img,None,fx=2, fy=2, interpolation = cv2.INTER_CUBIC)

# %%
cv2.namedWindow('res1')
cv2.namedWindow('res2')
cv2.namedWindow('res3')
cv2.resizeWindow('res1', rows*2, cols*2)
cv2.resizeWindow('res2', rows*2, cols*2)
cv2.resizeWindow('res3', rows*2, cols*2)

while(1):
    cv2.imshow('res1',res1)
    cv2.imshow('res2',res2)
    cv2.imshow('res3',res3)
    
    if cv2.waitKey(20) & 0xFF == 27:
        break
cv2.destroyAllWindows()

# %%
img = cv2.imread('opencv_logo.jpg')
rows,cols,_ = img.shape

M = np.float32([[1,0,100],[0,1,0]])
dst = cv2.warpAffine(img,M,(cols,rows))

cv2.imshow('img',img)
cv2.imshow('dst',dst)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# #### Rotation

# %%
M = cv2.getRotationMatrix2D((cols/2,rows/2),60,1)
dst = cv2.warpAffine(img,M,(cols,rows))

cv2.imshow('img',img)
cv2.imshow('dst',dst)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# #### Perspective Transformation

# %%
img = cv2.imread('dsu1.jpg')
rows,cols,ch = img.shape

pts1 = np.float32([[323,282],[761,310],[765,509],[322,534]])
pts2 = np.float32([[300,300],[800,300],[800,600],[300,600]])

M = cv2.getPerspectiveTransform(pts1,pts2)

dst = cv2.warpPerspective(img,M,(1100,900))

plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()

# %%
img = cv2.imread('dsu3.jpg')
rows,cols,ch = img.shape

pts1 = np.float32([[106,225],[700,162],[705,539],[110,496]])
pts2 = np.float32([[0,0],[1600,0],[1600,900],[0,900]])

M = cv2.getPerspectiveTransform(pts1,pts2)

dst = cv2.warpPerspective(img,M,(1600,900))

plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()

# %%
img = cv2.imread('IMG_6504.jpg')
rows,cols,ch = img.shape

pts1 = np.float32([[170,186],[97,1078],[810,1096],[764,191]])
pts2 = np.float32([[0,0],[0,1300],[900,1300],[900,0]])

M = cv2.getPerspectiveTransform(pts1,pts2)

dst = cv2.warpPerspective(img,M,(900,1300))

plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()
